# %% [markdown]
# Section 1: Mount Google Drive

# %%
# Import the drive module from google.colab
from google.colab import drive

# Mount Google Drive to access files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Section 2: Extract Dataset

# %%
import zipfile
import os

# Define the path to your zip file in Google Drive
zip_path = '/content/drive/MyDrive/Data Science/bus-stop-assess final.v2i.yolov8.zip'
# Define where to extract the dataset
extract_path = '/content/dataset'

# Create the directory if it doesn't exist
if not os.path.exists(extract_path):
    os.makedirs(extract_path)

# Unzip the dataset into the local Colab directory
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extraction from Drive completed!")
# Out:
# Dataset extraction from Drive completed!

# %% [markdown]
# Section 3: Configure data.yaml

# %%
import yaml

# Path to the dataset configuration file
yaml_path = '/content/dataset/data.yaml'

# Load the existing yaml data
with open(yaml_path, 'r') as f:
    data = yaml.safe_load(f)

# Update paths to match the local Colab environment
data['train'] = '/content/dataset/train/images'
data['val'] = '/content/dataset/valid/images'
data['test'] = '/content/dataset/test/images'

# Save the updated configuration back to the file
with open(yaml_path, 'w') as f:
    yaml.dump(data, f)

print("Configuration file updated successfully!")
# Out:
# Configuration file updated successfully!

# %% [markdown]
# Section 4: Training the Model (Weights & Training)

# %%
# !pip install ultralytics
import os
from ultralytics import YOLO

# 1. Load the pre-trained weights (YOLOv8)
model = YOLO('yolov8n.pt')

# 2. Start the training process
model.train(
    data='/content/dataset/data.yaml',
    epochs=100,
    imgsz=640,
    project='/content/drive/MyDrive/Thesis_Project_YOLOv8/training_results',
    name='bus_stop_v8_baseline',
    scale=0.5,
    perspective=0.0005,
    mosaic=1.0,
    mixup=0.2,
    degrees=10.0
)
print("YOLOv8 Training completed successfully!")
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.75-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.5.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.75-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.75 ultralytics-thop-2.0.20
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 108.3MB/s 0.1s
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/dataset/data.yaml, degrees=10.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=bus_stop_v5_baseline, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0005, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/Thesis_Project_YOLOv8/training_results, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/Thesis_Project_YOLOv8/training_results/bus_stop_v5_baseline, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 24.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,012,018 parameters, 3,012,002 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 102.5MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1423.7±802.5 MB/s, size: 99.3 KB)
# train: Scanning /content/dataset/train/labels... 822 images, 57 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 822/822 1.9Kit/s 0.4s
# train: New cache created: /content/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 931.1±669.7 MB/s, size: 108.5 KB)
# val: Scanning /content/dataset/valid/labels... 229 images, 13 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 229/229 1.4Kit/s 0.2s
# val: New cache created: /content/dataset/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/Thesis_Project_YOLOv8/training_results/bus_stop_v5_baseline/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/Thesis_Project_YOLOv8/training_results/bus_stop_v5_baseline
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.05G       1.68      3.489      1.388         43        640: 100% ━━━━━━━━━━━━ 52/52 2.5it/s 20.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.0it/s 4.1s
#                    all        229        740      0.965     0.0948      0.261       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.51G      1.563      2.397      1.318         27        640: 100% ━━━━━━━━━━━━ 52/52 2.8it/s 18.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2
5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.8it/s 2.9s
#                    all        229        740        0.9        0.8      0.865      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.52G      1.053     0.7244      1.036         41        640: 100% ━━━━━━━━━━━━ 52/52 2.8it/s 18.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.7it/s 4.7s
#                    all        229        740      0.919      0.786      0.863      0.554
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.52G     0.9135     0.5639     0.9511         17        640: 100% ━━━━━━━━━━━━ 52/52 2.8it/s 18.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.8it/s 2.9s
#                    all        229        740      0.945      0.759      0.858      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.52G     0.9179      0.541     0.9604         12        640: 100% ━━━━━━━━━━━━ 52/52 3.2it/s 16.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.4s
#                    all        229        740      0.918      0.782      0.854      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.52G     0.9003     0.5283     0.9561         21        640: 100% ━━━━━━━━━━━━ 52/52 3.6it/s 14.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.7it/s 4.7s
#                    all        229        740      0.914      0.772      0.856      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.52G     0.9031      0.523     0.9555         17        640: 100% ━━━━━━━━━━━━ 52/52 3.2it/s 16.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.6it/s 3.1s
#                    all        229        740      0.887      0.801      0.856      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.52G     0.8951     0.5173     0.9539         32        640: 100% ━━━━━━━━━━━━ 52/52 3.3it/s 15.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.6it/s 3.1s
#                    all        229        740      0.869      0.819      0.861      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.52G     0.8797     0.5086     0.9547         20        640: 100% ━━━━━━━━━━━━ 52/52 3.4it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.8it/s 4.5s
#                    all        229        740      0.917      0.781      0.865      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.52G     0.9018     0.5094     0.9604         11        640: 100% ━━━━━━━━━━━━ 52/52 3.3it/s 15.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.5it/s 3.2s
#                    all        229        740      0.917      0.776      0.855       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.52G     0.8759      0.502     0.9414         15        640: 100% ━━━━━━━━━━━━ 52/52 3.4it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.6it/s 3.1s
#                    all        229        740      0.878      0.805      0.858      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.52G     0.8748     0.4989     0.9433          7        640: 100% ━━━━━━━━━━━━ 52/52 3.4it/s 15.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.6it/s 3.1s
#                    all        229        740      0.886      0.806      0.867      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.52G     0.8834     0.5019     0.9476         26        640: 100% ━━━━━━━━━━━━ 52/52 3.3it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.6it/s 5.1s
#                    all        229        740      0.883      0.808      0.866      0.566
#
# 100 epochs completed in 0.633 hours.
# Optimizer stripped from /content/drive/MyDrive/Thesis_Project_YOLOv8/training_results/bus_stop_v5_baseline/weights/last.pt, 6.3MB
# Optimizer stripped from /content/drive/MyDrive/Thesis_Project_YOLOv8/training_results/bus_stop_v5_baseline/weights/best.pt, 6.3MB
#
# Validating /content/drive/MyDrive/Thesis_Project_YOLOv8/training_results/bus_stop_v5_baseline/weights/best.pt...
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.9it/s 4.3s
#                    all        229        740      0.921      0.781      0.865      0.566
#             route info         50         52      0.854      0.561       0.67      0.326
#               schedule         73         74      0.925      0.851      0.915      0.588
#                seating        132        142      0.919      0.795       0.86      0.568
#                shelter        114        116      0.959      0.931      0.969       0.77
#                   sign        144        190      0.959      0.743      0.863      0.496
#              trash can        144        166      0.912      0.807      0.912      0.646
# Speed: 0.3ms preprocess, 2.4ms inference, 0.0ms loss, 4.2ms postprocess per image
# Results saved to /content/drive/MyDrive/Thesis_Project_YOLOv8/training_results/bus_stop_v5_baseline
# YOLOv8 Training completed successfully!

# %% [markdown]
# Section 5: Model Inference (Testing on New Images)
#
# After training, we use the best-trained weights (best.pt) to run predictions on the test dataset to visualize how the model performs on unseen data.

# %%
import os
from ultralytics import YOLO

model_path = '/content/drive/MyDrive/Thesis_Project_YOLOv8/training_results/bus_stop_v8_baseline/weights/best.pt'
model = YOLO(model_path)

test_images_path = '/content/dataset/test/images'

if os.path.exists(test_images_path):
    results = model.predict(
        source=test_images_path,
        save=True,
        conf=0.25,
        project='/content/drive/MyDrive/Thesis_Project_YOLOv8',
        name='test_results_v8'
    )
    print("Inference completed for YOLOv8!")
else:
    print("Error: Test images directory not found.")
# Out:
# image 1/118 /content/dataset/test/images/1F5kE4ER0UZz8BDchBzLcA_jpg.rf.0c300b9c20a106c0a3a8f41cfb34a295.jpg: 640x640 1 seating, 1 shelter, 1 trash can, 9.1ms
# image 2/118 /content/dataset/test/images/210170_1_jpg.rf.6f4e4fedb92493635b2ff2f16010db06.jpg: 640x640 1 sign, 1 trash can, 8.0ms
# image 3/118 /content/dataset/test/images/211401_0_jpg.rf.a4671744c3127b679eede33211c5d91b.jpg: 640x640 1 trash can, 7.2ms
# image 4/118 /content/dataset/test/images/211997_0_jpg.rf.2bb3ca346f3f71378b912889146b78d9.jpg: 640x640 1 seating, 1 trash can, 10.2ms
# image 5/118 /content/dataset/test/images/212079_0_jpg.rf.4f75a99bfddaa3e3f2a0eda98319c7ec.jpg: 640x640 1 seating, 1 sign, 1 trash can, 7.2ms
# image 6/118 /content/dataset/test/images/212106_1_jpg.rf.b7db26c24c34b7e3e3d9fa99edb912dd.jpg: 640x640 1 sign, 7.2ms
# image 7/118 /content/dataset/test/images/212144_1_jpg.rf.32a2e1d323f5808ee9b4c72e4ee37af1.jpg: 640x640 1 route info, 1 schedule, 2 seatings, 1 shelter, 1 sign, 2 trash cans, 7.2ms
# image 8/118 /content/dataset/test/images/212161_1_jpg.rf.b0b83d8250933daffd9a6157dad45153.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 sign, 2 trash cans, 7.2ms
# image 9/118 /content/dataset/test/images/212233_1_jpg.rf.4c1fbc4aa0082010f70c51be12968ada.jpg: 640x640 1 seating, 7.2ms
# image 10/118 /content/dataset/test/images/212353_1_jpg.rf.0b4485d946c982933d77b09bcf26d606.jpg: 640x640 1 route info, 1 schedule, 1 seating, 1 shelter, 1 sign, 1 trash can, 7.2ms
# image 11/118 /content/dataset/test/images/212408_1_jpg.rf.c8757450588575b4ec54620b4ea53974.jpg: 640x640 2 schedules, 1 seating, 1 shelter, 1 trash can, 7.6ms
# image 12/118 /content/dataset/test/images/212479_0_jpg.rf.b714f08bf7293801e88853c1be1d078f.jpg: 640x640 1 shelter, 1 sign, 2 trash cans, 7.3ms
# image 13/118 /content/dataset/test/images/212510_1_jpg.rf.3abec226af134e8df5745f2eeaaaa349.jpg: 640x640 1 schedule, 2 seatings, 1 shelter, 1 sign, 2 trash cans, 7.2ms
# image 14/118 /content/dataset/test/images/212542_1_jpg.rf.2096573d432ea96d395507240e6bc79c.jpg: 640x640 1 sign, 7.4ms
# image 15/118 /content/dataset/test/images/212876_0_jpg.rf.b6d4fb971d88f6c27cf83731ac8b3bc9.jpg: 640x640 1 route info, 1 schedule, 1 seating, 1 shelter, 1 sign, 1 trash can, 7.2ms
# image 16/118 /content/dataset/test/images/213116_1_jpg.rf.475bd12cdb8f153aeb1365108571a884.jpg: 640x640 1 trash can, 8.4ms
# image 17/118 /content/dataset/test/images/213118_0_jpg.rf.b6d25f8f6e6ab9c4e15e4f8924ac6a97.jpg: 640x640 1 route info, 1 schedule, 1 seating, 1 shelter, 1 sign, 1 trash can, 7.2ms
# image 18/118 /content/dataset/test/images/213154_0_jpg.rf.0d5ca00620e974b7d9ed93a499fc8976.jpg: 640x640 1 route info, 1 seating, 2 signs, 7.2ms
# image 19/118 /content/dataset/test/images/213349_0_jpg.rf.525731d5a805911cc33ed6ee04952eb5.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 sign, 1 trash can, 7.7ms
# image 20/118 /content/dataset/test/images/213468_0_jpg.rf.4cc203b01e6f61222cab83b14170357d.jpg: 640x640 1 seating, 1 shelter, 1 trash can, 7.2ms
# image 21/118 /content/dataset/test/images/213590_0_jpg.rf.9141e801297d872d95d867770546578f.jpg: 640x640 1 seating, 2 signs, 1 trash can, 7.2ms
# image 22/118 /content/dataset/test/images/213610_1_jpg.rf.a0aa9552c49dac1107a8dc1381b99c3c.jpg: 544x640 1 schedule, 1 seating, 1 shelter, 1 sign, 2 trash cans, 45.0ms
# image 23/118 /content/dataset/test/images/213747_1_jpg.rf.f1a0704c14d1f2f94c77e191da764ea6.jpg: 640x640 1 seating, 1 trash can, 8.0ms
# image 24/118 /content/dataset/test/images/28SDym9HNlLHT-ZskPuxiw_jpg.rf.6ea5b97bdb65827f9855589cc025e27b.jpg: 640x640 1 route info, 1 seating, 2 signs, 1 trash can, 7.4ms
# image 25/118 /content/dataset/test/images/3HT0_ylbUgTWFCoRSEFoTA_jpg.rf.e9eeb5908c485b7de79eeaf01d10f2f1.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 trash can, 7.3ms
# image 26/118 /content/dataset/test/images/3RRlhy8Cnjly7q6nA2au2g_jpg.rf.0795d523cbb464f48a61b2b639f606bc.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 7.8ms
# image 27/118 /content/dataset/test/images/3flDhH3Xx91dOYZ93Fwfow_jpg.rf.7d6045add026f24ca08a129664d95d0b.jpg: 640x640 2 schedules, 1 seating, 1 shelter, 2 trash cans, 7.2ms
# image 28/118 /content/dataset/test/images/4sqpRMwfnJMVblZYYDHQNw_jpg.rf.a433fd5a4caa683c65493e3e9f8b3f86.jpg: 640x640 (no detections), 7.2ms
# image 29/118 /content/dataset/test/images/600048_1_jpg.rf.e364c1aebd1618aefafab15f9aa96869.jpg: 640x640 1 route info, 3 signs, 1 trash can, 11.2ms
# image 30/118 /content/dataset/test/images/900013_0_jpg.rf.f9a921e38233924ae90aab9781d628f5.jpg: 640x640 1 route info, 1 sign, 8.7ms
# image 31/118 /content/dataset/test/images/900314_1_jpg.rf.19a7e3847020694de4dac91ea4de9ea0.jpg: 640x640 1 route info, 1 schedule, 1 seating, 1 shelter, 2 signs, 1 trash can, 7.2ms
# image 32/118 /content/dataset/test/images/900501_1_jpg.rf.03b69162cb607d540a9a3900eaff39c6.jpg: 640x640 1 seating, 1 shelter, 1 sign, 7.2ms
# image 33/118 /content/dataset/test/images/900601_1_jpg.rf.b60030308c0e1b40e361dc9fd43627a2.jpg: 640x640 1 seating, 1 shelter, 2 trash cans, 7.2ms
# image 34/118 /content/dataset/test/images/900705_1_jpg.rf.9f6aaab79e337cfc95289626b2158910.jpg: 640x640 1 route info, 1 seating, 2 signs, 2 trash cans, 7.2ms
# image 35/118 /content/dataset/test/images/900940_1_jpg.rf.5c8c5f43630d0c2a30818ef22fe6b951.jpg: 640x640 1 seating, 1 sign, 9.5ms
# image 36/118 /content/dataset/test/images/900941_0_jpg.rf.79abd81d6f9a06711f5f79c90e731bd0.jpg: 640x640 1 seating, 1 trash can, 11.0ms
# image 37/118 /content/dataset/test/images/901031_1_jpg.rf.09630b68b3594686f155f07f7d09ca5d.jpg: 640x640 1 schedule, 1 seating, 1 sign, 1 trash can, 7.2ms
# image 38/118 /content/dataset/test/images/901796_0_jpg.rf.bf420315a6862577feff6dc69d80fec2.jpg: 640x640 1 sign, 1 trash can, 7.2ms
# image 39/118 /content/dataset/test/images/902233_0_jpg.rf.946fd40cdcc6011fdf23ee195cfcc69c.jpg: 576x640 1 schedule, 1 seating, 1 shelter, 1 trash can, 43.9ms
# image 40/118 /content/dataset/test/images/902259_0_jpg.rf.5fa74dd452a4dea509148c5d933317e8.jpg: 640x640 4 seatings, 1 shelter, 7.8ms
# image 41/118 /content/dataset/test/images/902317_0_jpg.rf.a0ffec0267957ff28b96fa39d126ced8.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 sign, 1 trash can, 7.2ms
# image 42/118 /content/dataset/test/images/902317_1_jpg.rf.d6c135cfb4c66b589738b5af698fa20e.jpg: 640x640 1 shelter, 7.3ms
# image 43/118 /content/dataset/test/images/902336_1_jpg.rf.32e50f369f456b00b749f81978fa5a29.jpg: 640x640 1 route info, 1 shelter, 1 sign, 1 trash can, 7.2ms
# image 44/118 /content/dataset/test/images/902375_0_jpg.rf.3794ffbfa86bf321f415705a6ece6218.jpg: 640x640 2 trash cans, 7.2ms
# image 45/118 /content/dataset/test/images/902375_1_jpg.rf.584c220b3a80e57d4cfa7b395fca1067.jpg: 640x640 1 seating, 1 shelter, 1 trash can, 8.4ms
# image 46/118 /content/dataset/test/images/902408_0_jpg.rf.3d0b1b25378c353aa037b54a8cd74abc.jpg: 640x640 1 sign, 7.2ms
# image 47/118 /content/dataset/test/images/902814_1_jpg.rf.9dad954d4cd6823371071280d719e652.jpg: 640x640 1 trash can, 7.2ms
# image 48/118 /content/dataset/test/images/902832_0_jpg.rf.8a031717924ee4a865405ecad7a26283.jpg: 640x640 1 seating, 1 trash can, 7.2ms
# image 49/118 /content/dataset/test/images/902853_0_jpg.rf.dba8bff7cc88ee3401cd07e95e39500e.jpg: 640x640 2 route infos, 1 schedule, 1 seating, 1 shelter, 1 sign, 2 trash cans, 7.2ms
# image 50/118 /content/dataset/test/images/902888_1_jpg.rf.e2182a45c4d6c3686847b6301695d6b1.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 trash can, 7.2ms
# image 51/118 /content/dataset/test/images/902915_1_jpg.rf.6dc862c49d46d87852dc2ce37fd27a94.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 trash can, 8.8ms
# image 52/118 /content/dataset/test/images/902923_1_jpg.rf.5e47cb389692973f37c5075a07cd97a3.jpg: 640x640 1 route info, 1 shelter, 2 signs, 1 trash can, 7.2ms
# image 53/118 /content/dataset/test/images/902968_1_jpg.rf.dd0d3e0538b2408c0b5af1f1fe6a2e10.jpg: 640x640 2 signs, 7.2ms
# image 54/118 /content/dataset/test/images/903078_0_jpg.rf.94a0d4acfcf1e05805be9c7c441c24ec.jpg: 640x640 1 seating, 1 shelter, 7.2ms
# image 55/118 /content/dataset/test/images/903107_0_jpg.rf.e1731fb43043016ca9816678055755a1.jpg: 640x640 1 route info, 2 signs, 7.2ms
# image 56/118 /content/dataset/test/images/903117_1_jpg.rf.e736ee3ac76ae4c5c50c749ae10ea441.jpg: 576x640 1 schedule, 2 seatings, 1 shelter, 1 sign, 1 trash can, 7.8ms
# image 57/118 /content/dataset/test/images/903578_0_jpg.rf.19f041909f375c2b188cf6271898bb75.jpg: 640x640 1 seating, 1 trash can, 8.0ms
# image 58/118 /content/dataset/test/images/903606_0_jpg.rf.1b5ab3119aed0eded380dd82584f8d00.jpg: 640x640 1 shelter, 1 trash can, 7.2ms
# image 59/118 /content/dataset/test/images/903618_0_jpg.rf.ba32ce28924a797b0de3a948d381b5d2.jpg: 640x640 1 route info, 1 schedule, 1 seating, 1 shelter, 2 signs, 1 trash can, 7.2ms
# image 60/118 /content/dataset/test/images/903659_1_jpg.rf.5eb12b2801e600a7a797027dc5e5e94f.jpg: 640x640 1 route info, 2 signs, 1 trash can, 9.3ms
# image 61/118 /content/dataset/test/images/903671_0_jpg.rf.28d94c093266af1fea111f4e9177a060.jpg: 640x640 2 seatings, 1 sign, 1 trash can, 7.3ms
# image 62/118 /content/dataset/test/images/903710_1_jpg.rf.4cca87f6242421652edad96d03d09d30.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 trash can, 7.4ms
# image 63/118 /content/dataset/test/images/903754_1_jpg.rf.c4562fd563c6b69467f015ed6a5e520e.jpg: 640x640 (no detections), 7.2ms
# image 64/118 /content/dataset/test/images/903911_0_jpg.rf.b90a7aa360e447b322d779914dde8479.jpg: 640x640 2 trash cans, 7.2ms
# image 65/118 /content/dataset/test/images/903917_1_jpg.rf.41dd871505a471106aede9bd8b550305.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 sign, 7.2ms
# image 66/118 /content/dataset/test/images/903994_1_jpg.rf.996b76046eb1031f6262fd5941d44ae1.jpg: 640x640 1 sign, 7.3ms
# image 67/118 /content/dataset/test/images/903995_1_jpg.rf.c59b20ec099b03a66fbab9c4b23492c8.jpg: 640x640 1 shelter, 1 sign, 12.5ms
# image 68/118 /content/dataset/test/images/904000_0_jpg.rf.eaf40b04c73d51ff81267ec4d9ab7e7f.jpg: 640x640 1 sign, 10.3ms
# image 69/118 /content/dataset/test/images/904007_1_jpg.rf.505f645ef729c10698578b58f4d7c2a3.jpg: 608x640 1 schedule, 1 seating, 1 shelter, 1 sign, 1 trash can, 43.7ms
# image 70/118 /content/dataset/test/images/904013_0_jpg.rf.e7f6b3c4634fdb44d383f8b4016221ea.jpg: 640x640 2 seatings, 1 shelter, 1 sign, 1 trash can, 8.0ms
# image 71/118 /content/dataset/test/images/904091_1_jpg.rf.520abedde30637c862e4a9047b7dc554.jpg: 640x640 1 seating, 1 trash can, 7.5ms
# image 72/118 /content/dataset/test/images/904350_1_jpg.rf.73150c4d9fb1be2448575330eae746ed.jpg: 640x640 1 route info, 1 seating, 1 shelter, 1 sign, 1 trash can, 7.2ms
# image 73/118 /content/dataset/test/images/904960_1_jpg.rf.e63e73f407efe5c2ddd912466ad60da8.jpg: 640x640 1 route info, 1 schedule, 1 seating, 1 shelter, 2 signs, 1 trash can, 7.2ms
# image 74/118 /content/dataset/test/images/905079_1_jpg.rf.c4edb8c5cc96297802db9287e7e487e0.jpg: 640x640 1 route info, 1 seating, 1 sign, 7.2ms
# image 75/118 /content/dataset/test/images/905410_0_jpg.rf.aadc72645fbd097f74c18ab59aa8d95f.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 8.6ms
# image 76/118 /content/dataset/test/images/905613_1_jpg.rf.9c4081f648934008e5d35c4154ffdaa1.jpg: 640x640 1 route info, 1 seating, 2 signs, 1 trash can, 7.2ms
# image 77/118 /content/dataset/test/images/905812_1_jpg.rf.9097f22950a020fc266fbf93d72cbf76.jpg: 640x640 1 sign, 1 trash can, 7.2ms
# image 78/118 /content/dataset/test/images/906044_0_jpg.rf.31346bcb0832f6d1a845c62f572477c2.jpg: 640x640 1 route info, 1 schedule, 1 shelter, 2 signs, 1 trash can, 7.2ms
# image 79/118 /content/dataset/test/images/906305_0_jpg.rf.f3bac16a8561914d71e68ab1517116af.jpg: 640x640 1 route info, 2 seatings, 2 signs, 1 trash can, 7.3ms
# image 80/118 /content/dataset/test/images/906393_0_jpg.rf.c50c7bfdacff40984396870573506dba.jpg: 640x640 1 route info, 1 seating, 1 sign, 1 trash can, 7.2ms
# image 81/118 /content/dataset/test/images/9QCmrHVbuMCblX4GJAFBsA_jpg.rf.49754cd3b34b9e3a6e1dd2ebd8a70a4f.jpg: 640x640 (no detections), 7.2ms
# image 82/118 /content/dataset/test/images/A0PNDXLi23f6XNvbQu45xw_jpg.rf.d0c746b35184909d9d88b09e4db5547d.jpg: 640x640 1 sign, 7.2ms
# image 83/118 /content/dataset/test/images/A1HFao6wmlNKV52eudjeaQ_jpg.rf.75b39617cca4abed3e25724cc38f8181.jpg: 640x640 1 seating, 1 shelter, 7.2ms
# image 84/118 /content/dataset/test/images/A69AUda4SJUXA2I6suQ1DA_jpg.rf.5fcdaf167733a57b04a93d50a14f2bf5.jpg: 640x640 (no detections), 7.3ms
# image 85/118 /content/dataset/test/images/DBI9sM_kb8Kf9JIkamc3gw_jpg.rf.ddbfe29de39997be5d39659ccf2373bb.jpg: 640x640 1 sign, 7.2ms
# image 86/118 /content/dataset/test/images/DZ9mwgUFndP4eq6VFZdI1Q_jpg.rf.cf391d44a00af4605e948ba2866c7178.jpg: 640x640 (no detections), 7.2ms
# image 87/118 /content/dataset/test/images/HmBeC9d_31ZciAAEkzDt1A_jpg.rf.7b94596493b3189e4644bfc1bba14398.jpg: 640x640 (no detections), 7.2ms
# image 88/118 /content/dataset/test/images/IuRbOWhQ5pYCvjZ6Hy_wbQ_jpg.rf.cd0ddbde332161421d3d5899d93089e6.jpg: 640x640 (no detections), 7.2ms
# image 89/118 /content/dataset/test/images/K7Sa6YjZ9iujOwDuGnBuNg_jpg.rf.a77cb0ef975765d78683e0b11c381d83.jpg: 640x640 1 sign, 1 trash can, 7.2ms
# image 90/118 /content/dataset/test/images/K_a_ESFZXFCS2NnbdMelqA_jpg.rf.f92bbb5f421f55bd47fac0802e5e492e.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 trash can, 7.2ms
# image 91/118 /content/dataset/test/images/KnN5TOGItWGp_eZo7hPvKA_jpg.rf.01a85d75ad84efa8598b1fe56ad64b49.jpg: 640x640 1 sign, 7.2ms
# image 92/118 /content/dataset/test/images/MA-Ohu0FkVi0ufvDX9r1cQ_jpg.rf.b4fa4cae20ec345cd60be20cafd14af0.jpg: 640x640 1 sign, 7.2ms
# image 93/118 /content/dataset/test/images/N8I9n00ojqionkBhyd2ttA_jpg.rf.4cf48e5ecb9488c84af21a2ccc0977e6.jpg: 640x640 1 route info, 1 schedule, 1 seating, 1 shelter, 1 sign, 10.0ms
# image 94/118 /content/dataset/test/images/SdYm4SeiByxDpfToNb_MHA_jpg.rf.3fc11f7d7eaff0cc4acbfc8485880876.jpg: 640x640 2 seatings, 1 trash can, 7.3ms
# image 95/118 /content/dataset/test/images/WvH_49uuJMmk_615Iwbhog_jpg.rf.7ab46f127737576db671a460b9cee9b8.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 7.2ms
# image 96/118 /content/dataset/test/images/YlLriJADK5oN0rEH9amnpQ_jpg.rf.3d9cb51f4ac661d6bf181fc3ae829f91.jpg: 640x640 1 shelter, 1 sign, 1 trash can, 7.2ms
# image 97/118 /content/dataset/test/images/c3H-Uw9WA8TmfVxeeUpWNw_jpg.rf.252016a5fc4b931635efb5447505e4bf.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 trash can, 7.2ms
# image 98/118 /content/dataset/test/images/doC62ZRxDcXyylrYkUmkZA_jpg.rf.5379e58c8d69807858ede74b15015f43.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 1 trash can, 10.5ms
# image 99/118 /content/dataset/test/images/hWpLrIxQr-jRhVuHHywzsA_jpg.rf.c9e85df6eaa5a30077ecdef5bf0f4d1a.jpg: 640x640 (no detections), 7.3ms
# image 100/118 /content/dataset/test/images/iNhYa7Wa7w_7CjmnF6NCxQ_jpg.rf.6ad1de8a927fd6dac0f9c55b0e494609.jpg: 640x640 1 route info, 2 seatings, 1 shelter, 1 sign, 1 trash can, 7.2ms
# image 101/118 /content/dataset/test/images/iTalAfJ_QaufEQzzX3KsoA_jpg.rf.1512310536ffd3d79abe87a42041c653.jpg: 640x640 1 sign, 7.3ms
# image 102/118 /content/dataset/test/images/iecAjItrpk42eAGmVC97pw_jpg.rf.718824866a9ec11853197441302082e6.jpg: 640x640 1 seating, 1 shelter, 7.4ms
# image 103/118 /content/dataset/test/images/lF2tdJVYKLhDqqcyhCWrqQ_jpg.rf.a56771394ac4a80a635c38980196034d.jpg: 640x640 1 seating, 1 shelter, 7.2ms
# image 104/118 /content/dataset/test/images/left_211972_1_jpg.rf.7f48b792d01310c36e9fcbdaa21146ac.jpg: 640x640 1 seating, 1 sign, 1 trash can, 7.2ms
# image 105/118 /content/dataset/test/images/left_903754_0_jpg.rf.27377a82fefd8700528fadd892d33067.jpg: 640x640 1 sign, 1 trash can, 7.2ms
# image 106/118 /content/dataset/test/images/left_903917_0_jpg.rf.62078e343de8502f0810db01f9d3f1cd.jpg: 640x640 1 shelter, 1 trash can, 7.2ms
# image 107/118 /content/dataset/test/images/left_qREr1Ty1wsbeq3yj7Pa_aA_jpg.rf.757fb6231dcb5f8c6cbd39aaaf1cf769.jpg: 448x640 1 seating, 1 shelter, 43.6ms
# image 108/118 /content/dataset/test/images/mjrTu_xcCDB68yarrqEouA_jpg.rf.dcd8e99ac318b63c5803b4ef2f60cf18.jpg: 640x640 1 seating, 1 shelter, 10.0ms
# image 109/118 /content/dataset/test/images/mulv8Shv2fGcsnkb-uQOMw_jpg.rf.b5209ed066386f038e9eaf3394521569.jpg: 640x640 1 seating, 1 sign, 7.2ms
# image 110/118 /content/dataset/test/images/njGrkxM5cVERBUVPcj_NMw_jpg.rf.b2a457f544bd27dc59b74c3badef785e.jpg: 640x640 1 trash can, 7.2ms
# image 111/118 /content/dataset/test/images/o-2VH0lWLrixuQzTYHAAdQ_jpg.rf.2b83199b098fb0149122cd28bad709b0.jpg: 640x640 1 sign, 7.2ms
# image 112/118 /content/dataset/test/images/right_903249_0_jpg.rf.988c1064d374fbc75667a1c93c4eb676.jpg: 640x640 1 sign, 7.2ms
# image 113/118 /content/dataset/test/images/right_qREr1Ty1wsbeq3yj7Pa_aA_jpg.rf.91634e0fd1e1ac26c08ea36c6d7a155e.jpg: 448x640 1 shelter, 1 trash can, 6.8ms
# image 114/118 /content/dataset/test/images/t6MRqrq2OR4gJRNQuFtDPw_jpg.rf.ba3f212f865cc3554e3c2895076ee8cf.jpg: 640x640 1 route info, 1 schedule, 1 seating, 1 shelter, 2 signs, 7.9ms
# image 115/118 /content/dataset/test/images/thRZyiytJNlYJS49pTqoFA_jpg.rf.01ed3f550c5090a354f104156b92b20b.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 7.2ms
# image 116/118 /content/dataset/test/images/uFpzgyaWE18a1MCGSvVlOg_jpg.rf.21037e4cad295a9e1dca85c8777d757b.jpg: 640x640 1 seating, 1 sign, 1 trash can, 7.2ms
# image 117/118 /content/dataset/test/images/uPTdoLPgHYGDAfp_9oieIg_jpg.rf.8bbf9d10cb9926903e725e44a1be3ad4.jpg: 640x640 2 schedules, 1 seating, 1 shelter, 1 trash can, 7.3ms
# image 118/118 /content/dataset/test/images/wn3UUYWRsMplGTJBf2rQXw_jpg.rf.b9bfaf7ed8b1bc3f598a6f04b9c35fa0.jpg: 640x640 1 schedule, 1 seating, 1 shelter, 7.2ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/drive/MyDrive/Thesis_Project_YOLOv8/test_results_v8
# Inference completed for YOLOv8!

# %% [markdown]
# Section 6: Quantitative Evaluation (Final Metrics)
#
# This section calculates the final performance metrics (mAP, Precision, Recall) using the test split of your dataset for the thesis report.

# %%
from ultralytics import YOLO

# 1. Load the best-trained model of YOLOv8
model_path = '/content/drive/MyDrive/Thesis_Project_YOLOv8/training_results/bus_stop_v8_baseline/weights/best.pt'
model = YOLO(model_path)

# 2. Run validation on the test split
metrics = model.val(data='/content/dataset/data.yaml', split='test')

# 3. Print the matrix for the thesis report table
print("-" * 30)
print(f"Final Results for YOLOv8 Baseline:")
print(f"mAP50: {metrics.box.map50:.3f}")
print(f"mAP50-95: {metrics.box.map:.3f}")
print(f"Precision: {metrics.box.mp:.3f}")
print(f"Recall: {metrics.box.mr:.3f}")
print("-" * 30)
# Out:
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2424.3±487.0 MB/s, size: 73.5 KB)
# val: Scanning /content/dataset/test/labels.cache... 118 images, 8 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 118/118 49.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all        118        380      0.943       0.81      0.886      0.604
#             route info         30         30      0.936      0.667      0.807      0.461
#               schedule         33         33      0.968      0.903       0.95       0.69
#                seating         71         72      0.841      0.806      0.882      0.558
#                shelter         61         61          1       0.95      0.964      0.793
#                   sign         75         96       0.98       0.75       0.84      0.507
#              trash can         76         88      0.931      0.784       0.87      0.615
# Speed: 6.2ms preprocess, 4.9ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to /content/runs/detect/val-3
# ------------------------------
# Final Results for YOLOv8 Baseline:
# mAP50: 0.886
# mAP50-95: 0.604
# Precision: 0.943
# Recall: 0.810
# ------------------------------
